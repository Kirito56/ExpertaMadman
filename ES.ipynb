# %%
from ES import graphic_card

# %%
from DefFact import DefFact

# %%
from Asserts import Asserts

# %%
def start(engine: int,
          delfacts: bool = False,
          numoffact: bool = False,
          modify: bool = False,
          clear: bool = False,
          rules: bool = False):
    if engine == 1:
        e = DefFact()
        e.reset()
        e.init_facts()
        print(e.facts)
        if delfacts and numoffact:
            num = int(input('Fact Number: '))
            e.retract(numoffact)
        elif clear:
            e.facts.clear()
        elif rules:
            e.run()
    elif engine == 2:
        e = Asserts()
        e.reset()
        e.init_facts()
        print(e.facts)
        if delfacts:
            e.retract(numoffact)

# %%
engine = int(input(f'Engine:\n1.\tDefFacts\n2.\tAsserts\t(50%\tcomplete)\nChoice:\t{int}\t-\t'))
delete = bool(input(f'Delete\tFact:\nEmpty.\tNo\n1.\tYes\nChoice:\t{int}\t-\t'))
clear = bool(input(f'Clear:\nEmpty.\tNo\n1.\tYes\nChoice:\t{int}\t-\t'))
rules = bool(input(f'Rules:\nEmpty.\tNo\n1.\tYes\nChoice:\t{int}\t-\t'))
print(f'Engine:\t{engine}\nDelete:\t{delete}\nClear:\t{clear}\nRules:\t{rules}')
if delete or clear or rules:
    numoffact = True
    start(engine, numoffact=numoffact, delfacts=delete, clear=clear, rules=rules)
# Out:
# Engine:
# 1.	DefFacts
# 2.	Asserts	(50%	complete)
# Choice:	<class 'int'>	-	 1
# Delete	Fact:
# Empty.	No
# 1.	Yes
# Choice:	<class 'int'>	-	 1
# Clear:
# Empty.	No
# 1.	Yes
# Choice:	<class 'int'>	-	 1
# Rules:
# Empty.	No
# 1.	Yes
# Choice:	<class 'int'>	-	 1
# Engine:	1
# Delete:	True
# Clear:	True
# Rules:	True
# ---------------------------------------------------------------------------
# SchemaUnexpectedTypeError                 Traceback (most recent call last)
# ~/experta/fact.py in validate(self)
#      87                 try:
# ---> 88                     field.validate(self[name])
#      89                 except Exception as exc:
#
# ~/experta/fact.py in validate(self, data)
#      30     def validate(self, data):
# ---> 31         self.validator.validate(unfreeze(data))
#      32
#
# ~/schema.py in validate(self, data)
#     310             else:
# --> 311                 raise SchemaUnexpectedTypeError(
#     312                     '%r should be instance of %r' % (data, s.__name__),
#
# SchemaUnexpectedTypeError: 'MSI_PCI-Ex_GeForce_GT_730' should be instance of 'bool'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_89/2978184884.py in <module>
#       6 if delete or clear or rules:
#       7     numoffact = True
# ----> 8     start(engine, numoffact=numoffact, delfacts=delete, clear=clear, rules=rules)
#
# /tmp/ipykernel_89/975188941.py in start(engine, delfacts, numoffact, modify, clear, rules)
#       7     if engine == 1:
#       8         e = DefFact()
# ----> 9         e.reset()
#      10         e.init_facts()
#      11         print(e.facts)
#
# ~/experta/engine.py in reset(self, **kwargs)
#     206
#     207         # Declare all facts yielded by deffacts
# --> 208         self.__declare(*chain.from_iterable(deffacts))
#     209
#     210         self.running = False
#
# ~/experta/engine.py in __declare(self, *facts)
#     223             last_inserted = None
#     224             for fact in facts:
# --> 225                 last_inserted = self.facts.declare(fact)
#     226
#     227             if not self.running:
#
# ~/experta/factlist.py in declare(self, fact)
#      68
#      69         # Validate fact, will raise on validation error.
# ---> 70         fact.validate()
#      71
#      72         fact_id = self._get_fact_id(fact)
#
# ~/experta/fact.py in validate(self)
#      88                     field.validate(self[name])
#      89                 except Exception as exc:
# ---> 90                     raise ValueError(
#      91                         "Invalid value on field %r for fact %r"
#      92                         % (name, self))
#
# ValueError: Invalid value on field 'name' for fact graphic_card(name='MSI_PCI-Ex_GeForce_GT_730', functions=frozenlist(['DirectX_12', 'OpenGL_4.4']), inputs=frozenlist(['DVI', 'VGA', 'HDMI']), memory=2, purpose='office', price=3000, producer='nVidia')
